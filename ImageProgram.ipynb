# %%
pip install --upgrade tensorflow-gpu
# Out:
# Requirement already up-to-date: tensorflow-gpu in /usr/local/lib/python3.6/dist-packages (2.1.0)
# ...

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.1.0'

# %%
import zipfile
with zipfile.ZipFile('//content/drive/My Drive/chest_xray.zip', 'r') as zip_ref: zip_ref.extractall('')

# %%
import cv2

# %%
# This is for color image reading
img = cv2.imread('/content/chest_xray/test/NORMAL/IM-0001-0001.jpeg')   
# img = cv2.imread('/content/chest_xray/test/NORMAL/IM-0001-0001.jpeg', 0) 0 is for black and white

# %%
img.shape
# Out:
# (1317, 1857, 3)

# %%
from google.colab.patches import cv2_imshow
# cv2.imshow(img, 'image') for locale
cv2_imshow(img)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
X = []
Y = []
import os
import numpy as np
images_name = os.listdir('/content/chest_xray/test/NORMAL')
for i in range(len(images_name)):
  try:
      img = cv2.imread('/content/chest_xray/test/NORMAL/' + images_name[i])
      print(img.shape)
      img = cv2.resize(img, (256, 256))
      X.append(img)
      Y.append(1)
  except:
    pass

images_name = os.listdir('/content/chest_xray/test/PNEUMONIA')
for i in range(len(images_name)):
  try:
      img = cv2.imread('/content/chest_xray/test/PNEUMONIA/' + images_name[i])
      print(img.shape)
      img = cv2.resize(img, (256, 256))
      X.append(img)
      Y.append(0)
  except:
    pass
# Out:
# (2382, 2746, 3)
# (1334, 1604, 3)
# (1620, 1992, 3)
# (1418, 1856, 3)
# (2071, 2022, 3)
# (1164, 1612, 3)
# (1334, 1890, 3)
# (2094, 2194, 3)
# (1332, 2187, 3)
# (824, 1168, 3)
# (1008, 1560, 3)
# (1706, 1741, 3)
# (1435, 1816, 3)
# (1600, 1952, 3)
# (716, 1124, 3)
# (1504, 1844, 3)
# (1337, 1778, 3)
# (747, 1226, 3)
# (1534, 1658, 3)
# (1945, 2214, 3)
# (898, 1094, 3)
# (897, 1396, 3)
# (813, 1256, 3)
# (2074, 2380, 3)
# (1056, 1504, 3)
# (2458, 2720, 3)
# (1597, 1894, 3)
# (1202, 1538, 3)
# (1907, 2165, 3)
# (1214, 1692, 3)
# (925, 1464, 3)
# (2057, 2498, 3)
# (1260, 1508, 3)
# (1048, 1586, 3)
# (1965, 2381, 3)
# (1505, 1726, 3)
# (1041, 1616, 3)
# (1979, 2517, 3)
# (904, 1368, 3)
# (1318, 1754, 3)
# (1837, 2031, 3)
# (1526, 2035, 3)
# (1033, 1550, 3)
# (906, 1460, 3)
# (1311, 1866, 3)
# (1485, 2198, 3)
# (1296, 2071, 3)
# (1936, 2345, 3)
# (1632, 1949, 3)
# (948, 1504, 3)
# (1064, 1536, 3)
# (1641, 1827, 3)
# (832, 1426, 3)
# (1357, 1890, 3)
# (1893, 2323, 3)
# (1442, 1724, 3)
# ...

# %%
X=np.array(X)
Y=np.array(Y)

# %%
X.shape
# Out:
# (624, 256, 256, 3)

# %%
X = X.reshape((624, 256*256*3))

# %%
X.shape
# Out:
# (624, 196608)

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from sklearn.metrics import confusion_matrix
LRelu = tf.keras.layers.LeakyReLU(alpha=0.3)

# %%
model = Sequential()
model.add(Dense(1024, input_dim=196608, activation='relu'))
model.add(BatchNormalization()) 
model.add(Dropout(0.2))
model.add(Dense(1024, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Dense(1024, activation='relu'))
model.add(BatchNormalization()) 
model.add(Dropout(0.2))
model.add(Dense(1024, activation='relu'))
model.add(BatchNormalization()) 
model.add(Dropout(0.2))
model.add(Dense(1024, activation='relu'))
model.add(BatchNormalization()) 
model.add(Dropout(0.2))
model.add(Dense(1024, activation='relu'))
model.add(BatchNormalization()) 
model.add(Dropout(0.2))
model.add(Dense(1024, activation='relu'))
model.add(BatchNormalization()) 
model.add(Dropout(0.2))
model.add(Dense(1024, activation=LRelu))
model.add(Dense(1, activation='sigmoid'))

# %%
# Compile the keras model     for multiclass, the loss is categorical cross entroy and for binary, it is binary cross entropy
model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics=['accuracy'])

# %%
# %%time
# fit the keras model on the dataset
model.fit(X, Y, epochs=50, batch_size=600)
# Out:
# Train on 624 samples
# Epoch 1/50
# 624/624 [==============================] - 2s 3ms/sample - loss: 0.7660 - accuracy: 0.5785
# Epoch 2/50
# 624/624 [==============================] - 0s 265us/sample - loss: 0.8179 - accuracy: 0.7035
# Epoch 3/50
# 624/624 [==============================] - 0s 279us/sample - loss: 0.8890 - accuracy: 0.7644
# Epoch 4/50
# 624/624 [==============================] - 0s 232us/sample - loss: 0.6638 - accuracy: 0.7612
# Epoch 5/50
# 624/624 [==============================] - 0s 254us/sample - loss: 0.6356 - accuracy: 0.8109
# Epoch 6/50
# 624/624 [==============================] - 0s 261us/sample - loss: 0.5145 - accuracy: 0.8013
# Epoch 7/50
# 624/624 [==============================] - 0s 263us/sample - loss: 0.6344 - accuracy: 0.8173
# Epoch 8/50
# 624/624 [==============================] - 0s 254us/sample - loss: 0.6779 - accuracy: 0.8253
# Epoch 9/50
# 624/624 [==============================] - 0s 249us/sample - loss: 0.8712 - accuracy: 0.7612
# ...

# %%
X_train = []
Y_train = []
import os
import numpy as np
images_name = os.listdir('/content/chest_xray/train/NORMAL')
for i in range(len(images_name)):
  try:
      img = cv2.imread('/content/chest_xray/train/NORMAL/' + images_name[i])
      print(img.shape)
      img = cv2.resize(img, (256, 256))
      X_train.append(img)
      Y_train.append(1)
  except:
    pass

images_name = os.listdir('/content/chest_xray/train/PNEUMONIA')
for i in range(len(images_name)):
  try:
      img = cv2.imread('/content/chest_xray/train/PNEUMONIA/' + images_name[i])
      print(img.shape)
      img = cv2.resize(img, (256, 256))
      X_train.append(img)
      Y_train.append(0)
  except:
    pass
# Out:
# Streaming output truncated to the last 5000 lines.
# (2016, 2032, 3)
# (1820, 2148, 3)
# (1688, 1654, 3)
# (1264, 1600, 3)
# (1318, 1570, 3)
# (1924, 2480, 3)
# (1183, 1454, 3)
# (1017, 1488, 3)
# (1248, 1604, 3)
# (1905, 1870, 3)
# (893, 1284, 3)
# (1028, 1530, 3)
# (1287, 1766, 3)
# (1187, 1616, 3)
# (1422, 1904, 3)
# (1403, 1662, 3)
# (1878, 1692, 3)
# (1241, 1662, 3)
# (1611, 1766, 3)
# (1078, 1454, 3)
# (967, 1172, 3)
# (1175, 1510, 3)
# (1514, 2302, 3)
# (1608, 1902, 3)
# (1028, 1348, 3)
# (1128, 1322, 3)
# (1418, 1582, 3)
# (1353, 1716, 3)
# (1909, 1906, 3)
# (1392, 1746, 3)
# (1480, 1840, 3)
# (1534, 1724, 3)
# (1754, 1928, 3)
# (1496, 1642, 3)
# (1480, 1620, 3)
# (2066, 2280, 3)
# (1345, 1736, 3)
# (1542, 1778, 3)
# (1318, 1774, 3)
# (1325, 1812, 3)
# (1109, 1372, 3)
# (1001, 1396, 3)
# (1909, 2566, 3)
# (1248, 1724, 3)
# (1194, 1572, 3)
# (904, 1120, 3)
# (1581, 1914, 3)
# (1280, 1626, 3)
# (1406, 1886, 3)
# (950, 1384, 3)
# (1194, 1662, 3)
# (1380, 1558, 3)
# ...

# %%
X_train=np.array(X_train)
Y_train=np.array(Y_train)

# %%
X_train.shape
# Out:
# (5216, 256, 256, 3)

# %%
X_train = X_train.reshape((5216, 256*256*3))

# %%
X_train.shape
# Out:
# (5216, 196608)

# %%
model = Sequential()
model.add(Dense(1024, input_dim=196608, activation='relu'))
model.add(BatchNormalization()) 
model.add(Dropout(0.4))
model.add(Dense(1024, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.4))
model.add(Dense(1024, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.4))
model.add(Dense(1024, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.4))
model.add(Dense(1024, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.4))
model.add(Dense(1024, activation='relu'))
model.add(BatchNormalization()) 
model.add(Dropout(0.4))
model.add(Dense(1024, activation='relu'))
model.add(BatchNormalization()) 
model.add(Dropout(0.4))
model.add(Dense(1024, activation='relu'))
model.add(BatchNormalization()) 
model.add(Dropout(0.4))
model.add(Dense(1024, activation='relu'))
model.add(BatchNormalization()) 
model.add(Dropout(0.4))
model.add(Dense(1024, activation='relu'))
model.add(BatchNormalization()) 
model.add(Dropout(0.4))
model.add(Dense(1024, activation=LRelu))
model.add(Dense(1, activation='sigmoid'))

# %%
# Compile the keras model     for multiclass, the loss is categorical cross entroy and for binary, it is binary cross entropy
model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics=['accuracy'])

# %%
# %%time
# fit the keras model on the dataset
model.fit(X_train, Y_train, epochs=50, batch_size=600, validation_data = (X, Y))
# Out:
# Train on 5216 samples, validate on 624 samples
# Epoch 1/50
# 5216/5216 [==============================] - 4s 699us/sample - loss: 0.7438 - accuracy: 0.6440 - val_loss: 31.4959 - val_accuracy: 0.6250
# Epoch 2/50
# 5216/5216 [==============================] - 1s 237us/sample - loss: 0.5157 - accuracy: 0.8027 - val_loss: 56.4554 - val_accuracy: 0.6250
# Epoch 3/50
# 5216/5216 [==============================] - 1s 235us/sample - loss: 0.3484 - accuracy: 0.8652 - val_loss: 143.8718 - val_accuracy: 0.6250
# Epoch 4/50
# 5216/5216 [==============================] - 1s 235us/sample - loss: 0.2758 - accuracy: 0.8894 - val_loss: 215.9247 - val_accuracy: 0.6250
# Epoch 5/50
# 5216/5216 [==============================] - 1s 234us/sample - loss: 0.2327 - accuracy: 0.9128 - val_loss: 156.9016 - val_accuracy: 0.6250
# Epoch 6/50
# 5216/5216 [==============================] - 1s 227us/sample - loss: 0.1928 - accuracy: 0.9298 - val_loss: 168.3364 - val_accuracy: 0.6250
# Epoch 7/50
# ...
